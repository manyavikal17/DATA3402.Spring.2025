# %% [markdown]
# # Lab 4- Object Oriented Programming
#
# For all of the exercises below, make sure you provide tests of your solutions.

# %% [markdown]
# 1. Write a "counter" class that can be incremented up to a specified maximum value, will print an error if an attempt is made to increment beyond that value, and allows reseting the counter.

# %%
class Counter:
    def __init__(self, max_value):
        self.max_value = max_value
        self.value = 0
        
    def increment(self, step = 1):
        if self.value + step <= self.max_value:
            self.value += step
            return True
        else:
            print("Maximum value has reached.")
            return False
        
    def reset(self):
        self.value = 0
    
    def get_value(self):
        return self.value

# %%
### Testing Solution

test = Counter(20)
for i in range(100):
    if not test.increment(3):
        break
    else:
        print(test.get_value())
test.reset()
# Out:
# 3
# 6
# 9
# 12
# 15
# 18
# Maximum value has reached.

# %% [markdown]
# 2. Copy and paste your solution to question 1 and modify it so that all the data held by the counter is private. Implement functions to check the value of the counter, check the maximum value, and check if the counter is at the maximum.

# %%
class Counter:
    def __init__(self, max_value):
        self.__max_value = max_value
        self.__value = 0
        
    def increment(self, step = 1):
        if self.__value + step <= self.__max_value:
            self.__value += step
            return True
        else:
            print("Maximum value has reached.")
            return False
        
    def reset(self):
        self.__value = 0
    
    def get_value(self):
        return self.__value
    
    def get_max_value(self):
        return self.__max_value
    
    def is_at_max(self):
        return self.__value == self.__max_value

# %%
### Testing Solution

test = Counter(20)
for i in range(100):
    if not test.increment(3):
        break
    else:
        print(test.get_value())
test.reset()

print("Max Value:", test.get_max_value())
print("Is at max:", test.is_at_max())
# Out:
# 3
# 6
# 9
# 12
# 15
# 18
# Maximum value has reached.
# Max Value: 20
# Is at max: False

# %% [markdown]
# 3. Implement a class to represent a rectangle, holding the length, width, and $x$ and $y$ coordinates of a corner of the object. Implement functions that compute the area and perimeter of the rectangle. Make all data members private and privide accessors to retrieve values of data members.

# %%
class Rectangle:
    def __init__(self, length, width, x, y):
        self.__length = length
        self.__width = width
        self.__x = x
        self.__y = y
        
    def get_length(self):
        return self.__length
    
    def get_width(self):
        return self.__width
    
    def get_x(self):
        return self.__x
    
    def get_y(self):
        return self.__y
    
    def set_length(self, length):
        if length > 0:
            self.__length = length
        else: 
            raise ValueError("Length must be a positive value.")
    
    def set_width(self, width):
        if width > 0:
            self.__width = width
        else: 
            raise ValueError("Width must be a positive value.")
    
    def set_x(self, x):
        self.__x = x
    
    def set_y(self, y):
        self.__y = y
    
    def get_area(self):
        return self.__length * self.__width
    
    def get_perimeter(self):
        return 2 * (self.__length + self.__width)

# %%
### Testing Solution
rectangle = Rectangle(10, 15, 2, 3)
print("Length:", rectangle.get_length())
print("Width:", rectangle.get_width())
print("X- Coordinate:", rectangle.get_x())
print("Y- Coordinate:", rectangle.get_y())
print("Area:", rectangle.get_area())
print("Perimeter:", rectangle.get_perimeter())
# Out:
# Length: 10
# Width: 15
# X- Coordinate: 2
# Y- Coordinate: 3
# Area: 150
# Perimeter: 50

# %% [markdown]
# 4. Implement a class to represent a circle, holding the radius and $x$ and $y$ coordinates of center of the object. Implement functions that compute the area and perimeter of the rectangle. Make all data members private and privide accessors to retrieve values of data members.

# %%
class Circle:
    def __init__(self, radius, x, y):
        self.__radius = radius
        self.__x = x
        self.__y = y
        
    def get_radius(self):
        return self.__radius
    
    def get_x(self):
        return self.__x
    
    def get_y(self):
        return self.__y
    
    def set_radius(self, length):
        if radius > 0:
            self.__radius = radius
        else: 
            raise ValueError("Radius must be a positive value.")
    
    def set_x(self, x):
        self.__x = x
    
    def set_y(self, y):
        self.__y = y
    
    def get_area(self):
        return 3.14 * self.__radius ** 2 
    
    def get_circumference(self):
        return 2 * 3.14 * self.__radius

# %%
### Testing Solution

circle = Circle(10, 1, 5)
print("Radius:", circle.get_radius())
print("X- Coordinate:", circle.get_x())
print("Y- Coordinate:", circle.get_y())
print("Area:", circle.get_area())
print("Circumference:", circle.get_circumference())
# Out:
# Radius: 10
# X- Coordinate: 1
# Y- Coordinate: 5
# Area: 314.0
# Circumference: 62.800000000000004

# %% [markdown]
# 5. Implement a common base class for the classes implemented in 3 and 4 above which implements all common methods as not implemented functions (virtual). Re-implement your regtangle and circule classes to inherit from the base class and overload the functions accordingly.

# %%
class Shape:
    def __init__(self, x, y):
        self.__x = x
        self.__y = y
    
    def area(self):
        raise NotImplementedError("Subclasses must implement this method")
        
    def perimeter(self):
        raise NotImplementedError("Subclasses must implement this method")
       
    def get_x(self):
        return self.__x
    
    def get_y(self):
        return self.__y
        
    def set_x(self, x):
        self.__x = x
    
    def set_y(self, y):
        self.__y = y
        
        
class Circle(Shape):
    def __init__(self, radius, x, y):
        super().__init__(x,y)
        self.__radius = radius
        
    def get_radius(self):
        return self.__radius
    
    def set_radius(self, radius):
        if radius > 0:
            self.__radius = radius
        else: 
            raise ValueError("Radius must be a positive value.")
    
    def get_area(self):
        return 3.14 * self.__radius ** 2 
    
    def get_circumference(self):
        return 2 * 3.14 * self.__radius

        


class Rectangle(Shape):
    def __init__(self, length, width, x, y):
        super().__init__(x,y)
        self.__length = length
        self.__width = width
        
    def get_length(self):
        return self.__length
    
    def get_width(self):
        return self.__width
    
    def set_length(self, length):
        if length > 0:
            self.__length = length
        else: 
            raise ValueError("Length must be a positive value.")
    
    def set_width(self, width):
        if width > 0:
            self.__width = width
        else: 
            raise ValueError("Width must be a positive value.")
    
    def get_area(self):
        return self.__length * self.__width
    
    def get_perimeter(self):
        return 2 * (self.__length + self.__width)

# %%
###n Testing Solution

circle = Circle(20, 1, 6)
print("Circle Radius:", circle.get_radius())
print("Circle X-Coordinate:", circle.get_x())
print("Circle Y-Coordinate:", circle.get_y())
print("Circle Area:", circle.get_area())
print("Circle Circumference:", circle.get_circumference())
    
rectangle = Rectangle(10, 15, 2, 3)
print("Rectangle Length:", rectangle.get_length())
print("Rectangle Width:", rectangle.get_width())
print("Rectangle X-Coordinate:", rectangle.get_x())
print("Rectangle Y-Coordinate:", rectangle.get_y())
print("Rectangle Area:", rectangle.get_area())
print("Rectangle Perimeter:", rectangle.get_perimeter())
# Out:
# Circle Radius: 20
# Circle X-Coordinate: 1
# Circle Y-Coordinate: 6
# Circle Area: 1256.0
# Circle Circumference: 125.60000000000001
# Rectangle Length: 10
# Rectangle Width: 15
# Rectangle X-Coordinate: 2
# Rectangle Y-Coordinate: 3
# Rectangle Area: 150
# Rectangle Perimeter: 50

# %% [markdown]
# 6. Implement a triangle class analogous to the rectangle and circle in question 5.

# %%
class Shape:
    def __init__(self, x, y):
        self.__x = x
        self.__y = y
    
    def area(self):
        raise NotImplementedError("Subclasses must implement this method")
        
    def perimeter(self):
        raise NotImplementedError("Subclasses must implement this method")
       
    def get_x(self):
        return self.__x
    
    def get_y(self):
        return self.__y
        
    def set_x(self, x):
        self.__x = x
    
    def set_y(self, y):
        self.__y = y
        
        
class Circle(Shape):
    def __init__(self, radius, x, y):
        super().__init__(x,y)
        self.__radius = radius
        
    def get_radius(self):
        return self.__radius
    
    def set_radius(self, radius):
        if radius > 0:
            self.__radius = radius
        else: 
            raise ValueError("Radius must be a positive value.")
    
    def get_area(self):
        return 3.14 * self.__radius ** 2 
    
    def get_circumference(self):
        return 2 * 3.14 * self.__radius

        


class Rectangle(Shape):
    def __init__(self, length, width, x, y):
        super().__init__(x,y)
        self.__length = length
        self.__width = width
        
    def get_length(self):
        return self.__length
    
    def get_width(self):
        return self.__width
    
    def set_length(self, length):
        if length > 0:
            self.__length = length
        else: 
            raise ValueError("Length must be a positive value.")
    
    def set_width(self, width):
        if width > 0:
            self.__width = width
        else: 
            raise ValueError("Width must be a positive value.")
    
    def get_area(self):
        return self.__length * self.__width
    
    def get_perimeter(self):
        return 2 * (self.__length + self.__width) 
    
    
    
class Triangle(Shape):
    def __init__(self, base, height, side1, side2, side3, x, y):
        super().__init__(x,y)
        self.__base = base
        self.__height = height
        self.__side1 = side1
        self.__side2 = side2
        self.__side3 = side3
        
    def get_base(self):
        return self.__base
    
    def get_height(self):
        return self.__height
    
    def get_sides(self):
        return self.__side1, self.__side2, self.__side3
    
    def set_base(self, base):
        if base > 0:
            self.__base = base
        else:
            raise ValueError("Base must be a positive value.")
    
    def set_height(self, height):
        if height > 0:
            self.__height = height
        else:
            raise ValueError("Height must be a positive value.")
            
    def set_sides(self, side1, side2, side3):
        if side1 > 0 and side2 > 0 and side3 > 0:
            self.__side1 = side1
            self.__side2 = side2
            self.__side3 = side3
        else:
            raise ValueError("All sides must be positive values.")
            
    def area(self):
        return 0.5 * self.__base * self.__height
    
    def perimeter(self):
        return self.__side1 + self.__side2 + self.__side3

# %%
###n Testing Solution

circle = Circle(20, 1, 6)
print("Circle Radius:", circle.get_radius())
print("Circle X-Coordinate:", circle.get_x())
print("Circle Y-Coordinate:", circle.get_y())
print("Area:", circle.get_area())
print("Circumference:", circle.get_circumference())
    
rectangle = Rectangle(10, 15, 2, 3)
print("Rectangle Length:", rectangle.get_length())
print("Rectangle Width:", rectangle.get_width())
print("Rectangle X-Coordinate:", rectangle.get_x())
print("Rectangle Y-Coordinate:", rectangle.get_y())
print("Area:", rectangle.get_area())
print("Perimeter:", rectangle.get_perimeter())

triangle = Triangle(10, 5, 8, 8, 8, 0, 0)
print("Triangle Base:", triangle.get_base())
print("Triangle Height:", triangle.get_height())
print("Triangle Sides:", triangle.get_sides())
print("Triangle X-Coordinate:", triangle.get_x())
print("Triangle Y-Coordinate:", triangle.get_y())
print("Area:", triangle.area())
print("Perimeter:", triangle.perimeter())
# Out:
# Circle Radius: 20
# Circle X-Coordinate: 1
# Circle Y-Coordinate: 6
# Area: 1256.0
# Circumference: 125.60000000000001
# Rectangle Length: 10
# Rectangle Width: 15
# Rectangle X-Coordinate: 2
# Rectangle Y-Coordinate: 3
# Area: 150
# Perimeter: 50
# Triangle Base: 10
# Triangle Height: 5
# Triangle Sides: (8, 8, 8)
# Triangle X-Coordinate: 0
# Triangle Y-Coordinate: 0
# Area: 25.0
# Perimeter: 24

# %% [markdown]
# 7. Add a function to the object classes, including the base, that returns a list of up to 16 pairs of  $x$ and $y$ points on the parameter of the object.

# %%
class Shape:
    def __init__(self, x, y):
        self.__x = x
        self.__y = y
    
    def area(self):
        raise NotImplementedError("Subclasses must implement this method")
        
    def perimeter(self):
        raise NotImplementedError("Subclasses must implement this method")
        
    def circumference(self):
        raise NotImplementedError("Subclasses must implement this method")
       
    def get_x(self):
        return self.__x
    
    def get_y(self):
        return self.__y
        
    def set_x(self, x):
        self.__x = x
    
    def set_y(self, y):
        self.__y = y
    
    def parameters(self):
        raise NotImplementedError("Subclasses must implement this method")
        
        
class Circle(Shape):
    def __init__(self, radius, x, y):
        super().__init__(x,y)
        self.__radius = radius
        
    def get_radius(self):
        return self.__radius
    
    def set_radius(self, radius):
        if radius > 0:
            self.__radius = radius
        else: 
            raise ValueError("Radius must be a positive value.")
    
    def get_area(self):
        return 3.14 * self.__radius ** 2 
    
    def get_circumference(self):
        return 2 * 3.14 * self.__radius
    
    def get_boundary_points(self):
        points = []
        step = 360 // 16
        for i in range(16):
            angle = step * i
            x_offset = round(self.__radius * (angle % 4) / 2, 2)
            y_offset = round(self.__radius * ((angle + 90) % 4) / 2, 2)
            points.append((self.get_x() + x_offset, self.get_y() + y_offset))
        return points

        


class Rectangle(Shape):
    def __init__(self, length, width, x, y):
        super().__init__(x,y)
        self.__length = length
        self.__width = width
        
    def get_length(self):
        return self.__length
    
    def get_width(self):
        return self.__width
    
    def set_length(self, length):
        if length > 0:
            self.__length = length
        else: 
            raise ValueError("Length must be a positive value.")
    
    def set_width(self, width):
        if width > 0:
            self.__width = width
        else: 
            raise ValueError("Width must be a positive value.")
    
    def get_area(self):
        return self.__length * self.__width
    
    def get_perimeter(self):
        return 2 * (self.__length + self.__width)
    
    def get_boundary_points(self):
        points = []
        step_x = self.__length / 4
        step_y = self.__width / 4
        for i in range(4):
            points.append((self.get_x() + i * step_x, self.get_y()))
            points.append((self.get_x() + i * step_x, self.get_y() + self.__width))
            points.append((self.get_x(), self.get_y() + i * step_y))
            points.append((self.get_x() + self.__length, self.get_y() + i * step_y))
        return points[:16]

    
    
class Triangle(Shape):
    def __init__(self, base, height, side1, side2, side3, x, y):
        super().__init__(x,y)
        self.__base = base
        self.__height = height
        self.__side1 = side1
        self.__side2 = side2
        self.__side3 = side3
        
    def get_base(self):
        return self.__base
    
    def get_height(self):
        return self.__height
    
    def get_sides(self):
        return self.__side1, self.__side2, self.__side3
    
    def set_base(self, base):
        if base > 0:
            self.__base = base
        else:
            raise ValueError("Base must be a positive value.")
    
    def set_height(self, height):
        if height > 0:
            self.__height = height
        else:
            raise ValueError("Height must be a positive value.")
            
    def set_sides(self, side1, side2, side3):
        if side1 > 0 and side2 > 0 and side3 > 0:
            self.__side1 = side1
            self.__side2 = side2
            self.__side3 = side3
        else:
            raise ValueError("All sides must be positive values.")
            
    def area(self):
        return 0.5 * self.__base * self.__height
    
    def perimeter(self):
        return self.__side1 + self.__side2 + self.__side3
    
    def get_boundary_points(self):
        points = [(self.get_x(), self.get_y()),
                (self.get_x() + self.__base, self.get_y()),
                (self.get_x() + self.__base / 2, self.get_y() + self.__height)]
        step = self.__base // 5
        for i in range(1, 5):
            points.append((self.get_x() + i * step, self.get_y()))
        step = self.__height // 5
        for i in range(1, 5):
            points.append((self.get_x() + self.__base / 2, self.get_y() + i * step))
        return points[:16]

# %%
### Testing Solution

circle = Circle(15, 1, 3)
print("Circle Boundary Points:", circle.get_boundary_points())
    
rectangle = Rectangle(12, 16, 2, 2)
print("Rectangle Boundary Points:", rectangle.get_boundary_points())
    
triangle = Triangle(10, 5, 8, 8, 8, 0, 0)
print("Triangle Boundary Points:", triangle.get_boundary_points())
# Out:
# Circle Boundary Points: [(1.0, 18.0), (16.0, 3.0), (1.0, 18.0), (16.0, 3.0), (1.0, 18.0), (16.0, 3.0), (1.0, 18.0), (16.0, 3.0), (1.0, 18.0), (16.0, 3.0), (1.0, 18.0), (16.0, 3.0), (1.0, 18.0), (16.0, 3.0), (1.0, 18.0), (16.0, 3.0)]
# Rectangle Boundary Points: [(2.0, 2), (2.0, 18), (2, 2.0), (14, 2.0), (5.0, 2), (5.0, 18), (2, 6.0), (14, 6.0), (8.0, 2), (8.0, 18), (2, 10.0), (14, 10.0), (11.0, 2), (11.0, 18), (2, 14.0), (14, 14.0)]
# Triangle Boundary Points: [(0, 0), (10, 0), (5.0, 5), (2, 0), (4, 0), (6, 0), (8, 0), (5.0, 1), (5.0, 2), (5.0, 3), (5.0, 4)]

# %% [markdown]
# 8. Add a function to the object classes, including the base, that tests if a given set of $x$ and $y$ coordinates are inside of the object. You'll have to think through how to determine if a set of coordinates are inside an object for each object type.

# %%
class Shape:
    def __init__(self, x, y):
        self.__x = x
        self.__y = y
    
    def area(self):
        raise NotImplementedError("Subclasses must implement this method")
        
    def perimeter(self):
        raise NotImplementedError("Subclasses must implement this method")
        
    def circumference(self):
        raise NotImplementedError("Subclasses must implement this method")
       
    def get_x(self):
        return self.__x
    
    def get_y(self):
        return self.__y
        
    def set_x(self, x):
        self.__x = x
    
    def set_y(self, y):
        self.__y = y
    
    def parameters(self):
        raise NotImplementedError("Subclasses must implement this method")

    def is_inside(self, x, y):
        raise NotImplementedError("Subclasses must implement this method")

        
class Circle(Shape):
    def __init__(self, radius, x, y):
        super().__init__(x,y)
        self.__radius = radius
        
    def get_radius(self):
        return self.__radius
    
    def set_radius(self, radius):
        if radius > 0:
            self.__radius = radius
        else: 
            raise ValueError("Radius must be a positive value.")
    
    def get_area(self):
        return 3.14 * self.__radius ** 2 
    
    def get_circumference(self):
        return 2 * 3.14 * self.__radius
    
    def get_boundary_points(self):
        points = []
        step = 360 // 16
        for i in range(16):
            angle = step * i
            x_offset = round(self.__radius * (angle % 4) / 2, 2)
            y_offset = round(self.__radius * ((angle + 90) % 4) / 2, 2)
            points.append((self.get_x() + x_offset, self.get_y() + y_offset))
        return points
    
    def is_inside(self, x, y):
        return (x - self.get_x())**2 + (y - self.get_y())**2 <= self.__radius**2

    
    

class Rectangle(Shape):
    def __init__(self, length, width, x, y):
        super().__init__(x,y)
        self.__length = length
        self.__width = width
        
    def get_length(self):
        return self.__length
    
    def get_width(self):
        return self.__width
    
    def set_length(self, length):
        if length > 0:
            self.__length = length
        else: 
            raise ValueError("Length must be a positive value.")
    
    def set_width(self, width):
        if width > 0:
            self.__width = width
        else: 
            raise ValueError("Width must be a positive value.")
    
    def get_area(self):
        return self.__length * self.__width
    
    def get_perimeter(self):
        return 2 * (self.__length + self.__width)
    
    def get_boundary_points(self):
        points = []
        step_x = self.__length / 4
        step_y = self.__width / 4
        for i in range(4):
            points.append((self.get_x() + i * step_x, self.get_y()))
            points.append((self.get_x() + i * step_x, self.get_y() + self.__width))
            points.append((self.get_x(), self.get_y() + i * step_y))
            points.append((self.get_x() + self.__length, self.get_y() + i * step_y))
        return points[:16]
    
    def is_inside(self,x, y):
        return self.get_x() <= x <= self.get_x() + self.__length and self.get_y() <= y <= self.get_y() + self.__width

        

    
class Triangle(Shape):
    def __init__(self, base, height, side1, side2, side3, x, y):
        super().__init__(x,y)
        self.__base = base
        self.__height = height
        self.__side1 = side1
        self.__side2 = side2
        self.__side3 = side3
        
    def get_base(self):
        return self.__base
    
    def get_height(self):
        return self.__height
    
    def get_sides(self):
        return self.__side1, self.__side2, self.__side3
    
    def set_base(self, base):
        if base > 0:
            self.__base = base
        else:
            raise ValueError("Base must be a positive value.")
    
    def set_height(self, height):
        if height > 0:
            self.__height = height
        else:
            raise ValueError("Height must be a positive value.")
            
    def set_sides(self, side1, side2, side3):
        if side1 > 0 and side2 > 0 and side3 > 0:
            self.__side1 = side1
            self.__side2 = side2
            self.__side3 = side3
        else:
            raise ValueError("All sides must be positive values.")
            
    def area(self):
        return 0.5 * self.__base * self.__height
    
    def perimeter(self):
        return self.__side1 + self.__side2 + self.__side3
    
    def get_boundary_points(self):
        points = [(self.get_x(), self.get_y()),
                (self.get_x() + self.__base, self.get_y()),
                (self.get_x() + self.__base / 2, self.get_y() + self.__height)]
        step = self.__base // 5
        for i in range(1, 5):
            points.append((self.get_x() + i * step, self.get_y()))
        step = self.__height // 5
        for i in range(1, 5):
            points.append((self.get_x() + self.__base / 2, self.get_y() + i * step))
        return points[:16]
    
    def is_inside(self, x, y):
        area_total = self.area()
        area1 = 0.5 * abs(self.get_x() * (self.get_y() + self.__height - y) + (self.get_x() + self.__base / 2) * (y - self.get_y()) + x * (self.get_y() - (self.get_y() + self.__height)))
        area2 = 0.5 * abs(x * (self.get_y() + self.__height - self.get_y()) + (self.get_x() + self.__base / 2) * (self.get_y() - y) + self.get_x() * (y - (self.get_y() + self.__height)))
        area3 = 0.5 * abs(self.get_x() * (self.get_y() - y) + x * ((self.get_y() + self.__height) - self.get_y()) + (self.get_x() + self.__base / 2) * (y - self.get_y()))
        return round(area1 + area2 + area3, 5) == round(area_total, 5)

# %%
### Testing Code

circle = Circle(10, 5, 5)
print("Circle is inside:", circle.is_inside(6,6))

rectangle = Rectangle(10, 5, 2, 3)
print("Rectangle is inside:", rectangle.is_inside(5,5))

triangle = Triangle(10, 5, 8, 8, 8, 0, 0)
print("Triangle is inside:", triangle.is_inside(5,2))
# Out:
# Circle is inside: True
# Rectangle is inside: True
# Triangle is inside: False

# %% [markdown]
# 9. Add a function in the base class of the object classes that returns true/false testing that the object overlaps with another object.

# %%
class Shape:
    def __init__(self, x, y):
        self.__x = x
        self.__y = y
    
    def area(self):
        raise NotImplementedError("Subclasses must implement this method")
        
    def perimeter(self):
        raise NotImplementedError("Subclasses must implement this method")
        
    def circumference(self):
        raise NotImplementedError("Subclasses must implement this method")
       
    def get_x(self):
        return self.__x
    
    def get_y(self):
        return self.__y
        
    def set_x(self, x):
        self.__x = x
    
    def set_y(self, y):
        self.__y = y
    
    def parameters(self):
        raise NotImplementedError("Subclasses must implement this method")

    def is_inside(self, x, y):
        raise NotImplementedError("Subclasses must implement this method")
   
    def overlaps(self, other):
        for x, y in other.get_boundary_points():
            if self.is_inside(x, y):
                return True
        return False
    
        
class Circle(Shape):
    def __init__(self, radius, x, y):
        super().__init__(x,y)
        self.__radius = radius
        
    def get_radius(self):
        return self.__radius
    
    def set_radius(self, radius):
        if radius > 0:
            self.__radius = radius
        else: 
            raise ValueError("Radius must be a positive value.")
    
    def get_area(self):
        return 3.14 * self.__radius ** 2 
    
    def get_circumference(self):
        return 2 * 3.14 * self.__radius
    
    def get_boundary_points(self):
        points = []
        step = 360 // 16
        for i in range(16):
            angle = step * i
            x_offset = round(self.__radius * (angle % 4) / 2, 2)
            y_offset = round(self.__radius * ((angle + 90) % 4) / 2, 2)
            points.append((self.get_x() + x_offset, self.get_y() + y_offset))
        return points
    
    def is_inside(self, x, y):
        return (x - self.get_x())**2 + (y - self.get_y())**2 <= self.__radius**2

    
    

class Rectangle(Shape):
    def __init__(self, length, width, x, y):
        super().__init__(x,y)
        self.__length = length
        self.__width = width
        
    def get_length(self):
        return self.__length
    
    def get_width(self):
        return self.__width
    
    def set_length(self, length):
        if length > 0:
            self.__length = length
        else: 
            raise ValueError("Length must be a positive value.")
    
    def set_width(self, width):
        if width > 0:
            self.__width = width
        else: 
            raise ValueError("Width must be a positive value.")
    
    def get_area(self):
        return self.__length * self.__width
    
    def get_perimeter(self):
        return 2 * (self.__length + self.__width)
    
    def get_boundary_points(self):
        points = []
        step_x = self.__length / 4
        step_y = self.__width / 4
        for i in range(4):
            points.append((self.get_x() + i * step_x, self.get_y()))
            points.append((self.get_x() + i * step_x, self.get_y() + self.__width))
            points.append((self.get_x(), self.get_y() + i * step_y))
            points.append((self.get_x() + self.__length, self.get_y() + i * step_y))
        return points[:16]
    
    def is_inside(self,x, y):
        return self.get_x() <= x <= self.get_x() + self.__length and self.get_y() <= y <= self.get_y() + self.__width

        

    
class Triangle(Shape):
    def __init__(self, base, height, side1, side2, side3, x, y):
        super().__init__(x,y)
        self.__base = base
        self.__height = height
        self.__side1 = side1
        self.__side2 = side2
        self.__side3 = side3
        
    def get_base(self):
        return self.__base
    
    def get_height(self):
        return self.__height
    
    def get_sides(self):
        return self.__side1, self.__side2, self.__side3
    
    def set_base(self, base):
        if base > 0:
            self.__base = base
        else:
            raise ValueError("Base must be a positive value.")
    
    def set_height(self, height):
        if height > 0:
            self.__height = height
        else:
            raise ValueError("Height must be a positive value.")
            
    def set_sides(self, side1, side2, side3):
        if side1 > 0 and side2 > 0 and side3 > 0:
            self.__side1 = side1
            self.__side2 = side2
            self.__side3 = side3
        else:
            raise ValueError("All sides must be positive values.")
            
    def area(self):
        return 0.5 * self.__base * self.__height
    
    def perimeter(self):
        return self.__side1 + self.__side2 + self.__side3
    
    def get_boundary_points(self):
        points = [(self.get_x(), self.get_y()),
                (self.get_x() + self.__base, self.get_y()),
                (self.get_x() + self.__base / 2, self.get_y() + self.__height)]
        step = self.__base // 5
        for i in range(1, 5):
            points.append((self.get_x() + i * step, self.get_y()))
        step = self.__height // 5
        for i in range(1, 5):
            points.append((self.get_x() + self.__base / 2, self.get_y() + i * step))
        return points[:16]
    
    def is_inside(self, x, y):
        area_total = self.area()
        area1 = 0.5 * abs(self.get_x() * (self.get_y() + self.__height - y) + (self.get_x() + self.__base / 2) * (y - self.get_y()) + x * (self.get_y() - (self.get_y() + self.__height)))
        area2 = 0.5 * abs(x * (self.get_y() + self.__height - self.get_y()) + (self.get_x() + self.__base / 2) * (self.get_y() - y) + self.get_x() * (y - (self.get_y() + self.__height)))
        area3 = 0.5 * abs(self.get_x() * (self.get_y() - y) + x * ((self.get_y() + self.__height) - self.get_y()) + (self.get_x() + self.__base / 2) * (y - self.get_y()))
        return round(area1 + area2 + area3, 5) == round(area_total, 5)

# %%
### Testing Solution

circle = Circle(10, 5, 5)
rectangle = Rectangle(10, 5, 2, 3)
triangle = Triangle(10, 5, 8, 8, 8, 0, 0)

print("Circle is inside:", circle.is_inside(6,6))
print("Rectangle is inside:", rectangle.is_inside(5,5))
print("Triangle is inside:", triangle.is_inside(5,2))
print("Circle overlaps Rectangle:", circle.overlaps(rectangle))
print("Rectangle overlaps Triangle:", rectangle.overlaps(triangle))
# Out:
# Circle is inside: True
# Rectangle is inside: True
# Triangle is inside: False
# Circle overlaps Rectangle: True
# Rectangle overlaps Triangle: True

# %% [markdown]
# 10. Copy the `Canvas` class from lecture to in a python file creating a `paint` module. Copy your classes from above into the module and implement paint functions. Implement a `CompoundShape` class. Create a simple drawing demonstrating that all of your classes are working.

# %%
import math
from Paint import Canvas, Rectangle, Circle, Triangle, CompoundShape

canvas = Canvas(40, 20)

circle = Circle(5, 10, 10)
rectangle = Rectangle(8, 4, 0, 25)
triangle = Triangle(6, 4, 6, 5, 7, 16, 2)

circle.paint(canvas)
rectangle.paint(canvas)
triangle.paint(canvas)
canvas.display()
# Out:
#                          ****
#                          ****
#                          ****
#                          ****
#                          ****
#           *              ****
#        *******           ****
#       *********          ****
#       *********
#       *********
#      ***********
#       *********
#       *********
#       *********
#        *******
#           *
#   ****
#    ***
#     **
#      *

# %% [markdown]
# 11. Create a `RasterDrawing` class. Demonstrate that you can create a drawing made of several shapes, paint the drawing, modify the drawing, and paint it again.

# %%
import math
from Paint import Canvas, Rectangle, Circle, Triangle, Shape

class RasterDrawing:
    def __init__(self, canvas):
        self.canvas = canvas
        self.shapes = []
    
    def add_shape(self, shape):
        self.shapes.append(shape)
        
    def remove_shape(self, shape):
        if shape in self.shapes:
            self.shapes.remove(shape)
    
    def paint(self):
        self.canvas.clear_canvas()
        for shape in self.shapes:
            shape.paint(self.canvas)
    
    def display(self):
        self.canvas.display()


canvas = Canvas(40,20)

drawing = RasterDrawing(canvas)

circle = Circle(5, 10, 10)
rectangle = Rectangle(8, 4, 0, 25)
triangle = Triangle(6, 4, 6, 5, 7, 16, 2)

drawing.add_shape(circle)
drawing.add_shape(rectangle)
drawing.add_shape(triangle)

print("First:")
drawing.paint()
drawing.display()
    
circle.set_x(5)        ### Changing the circle's row
circle.set_y(5)        ### Changing the circle's column
circle.set_radius(3)   ### Making the circle smaller
    
print("Second:")
drawing.paint()
drawing.display()
# Out:
# First:
#                          ****
#                          ****
#                          ****
#                          ****
#                          ****
#           *              ****
#        *******           ****
#       *********          ****
#       *********
#       *********
#      ***********
#       *********
#       *********
#       *********
#        *******
#           *
#   ****
#    ***
#     **
#      *
# Second:
#                          ****
#                          ****
#      *                   ****
#    *****                 ****
#    *****                 ****
#   *******                ****
#    *****                 ****
#    *****                 ****
#      *
#
#
#
#
#
#
#
#   ****
#    ***
#     **
#      *

# %% [markdown]
# 12. Implement the ability to load/save raster drawings and demonstate that your method works. One way to implement this ability:
#
#    * Overload `__repr__` functions of all objects to return strings of the python code that would construct the object.
#
#    * In the save method of raster drawing class, store the representations into the file.
#    * Write a loader function that reads the file and uses `eval` to instantiate the object.
#
# For example:

# %%
class foo:
    def __init__(self,a,b=None):
        self.a=a
        self.b=b
        
    def __repr__(self):
        return "foo("+repr(self.a)+","+repr(self.b)+")"
    
    def save(self,filename):
        f=open(filename,"w")
        f.write(self.__repr__())
        f.close()
        
   
def foo_loader(filename):
    f=open(filename,"r")
    tmp=eval(f.read())
    f.close()
    return tmp

# %%
# Test
print(repr(foo(1,"hello")))
# Out:
# foo(1,'hello')

# %%
# Create an object and save it
ff=foo(1,"hello")
ff.save("Test.foo")

# %%
# Check contents of the saved file
# !cat Test.foo
# Out:
# foo(1,'hello')

# %%
# Load the object
ff_reloaded=foo_loader("Test.foo")
ff_reloaded
# Out:
# foo(1,'hello')

# %%
from Paint import Canvas, Rectangle, Circle, Triangle, Shape

class RasterDrawing:
    def __init__(self, canvas, shapes= None):
        self.canvas = canvas
        self.shapes = shapes if isinstance(shapes, list) else []
    
    def add_shape(self, shape):
        self.shapes.append(shape)
        
    def remove_shape(self, shape):
        if shape in self.shapes:
            self.shapes.remove(shape)
    
    def paint(self):
        self.canvas.clear_canvas()
        for shape in self.shapes:
            shape.paint(self.canvas)
    
    def display(self):
        self.canvas.display()
        
    def save(self, filename):
        with open(filename, "w") as f:
            f.write(repr(self.shapes))
    
    def __repr__(self):
        return "{repr(self.shapes)})"
    
def load_draw(filename, canvas):
    with open(filename,"r") as f:
        shapes = eval(f.read())
    if not isinstance(shapes, list):
        raise TypeError("Loaded data is not a list of shapes.")
    
    return RasterDrawing(canvas, shapes)
    
canvas = Canvas(40,20)

drawing = RasterDrawing(canvas)

circle = Circle(5, 10, 10)
rectangle = Rectangle(8, 4, 0, 15)
triangle = Triangle(6, 4, 6, 5, 7, 16, 2)

drawing.add_shape(circle)
drawing.add_shape(rectangle)
drawing.add_shape(triangle)

print("First")
drawing.paint()
drawing.display()

drawing.save("drawing.txt")

load_drawing = load_draw("drawing.txt", canvas)
print("Loading Drawing:")
load_drawing.paint()
load_drawing.display()
# Out:
# First
#                ****
#                ****
#                ****
#                ****
#                ****
#           *    ****
#        ******* ****
#       *************
#       *********
#       *********
#      ***********
#       *********
#       *********
#       *********
#        *******
#           *
#   ****
#    ***
#     **
#      *
# Loading Drawing:
#                ****
#                ****
#                ****
#                ****
#                ****
#           *    ****
#        ******* ****
#       *************
#       *********
#       *********
#      ***********
#       *********
#       *********
#       *********
#        *******
#           *
#   ****
#    ***
#     **
#      *
